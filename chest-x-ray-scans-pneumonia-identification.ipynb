# %% [markdown]
# # Chest X-Ray Scans Pneumonia Identification
#
# This notebook uses a simple CNN.

# %% [markdown]
# First, we import all the needed dependencies

# %%
import numpy as np # linear algebra
import tensorflow as tf
import keras
import os
import shutil
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
from sklearn.metrics import confusion_matrix
import skimage
from skimage import exposure
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import keras.backend as K

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load and View Data

# %%
image_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/'

# %% [markdown]
# The images that are originally present aren't very clear. They have very low contrast. So, we use a combination of Adaptive Histogram Equalization and standard Histogram Equalization on all images

# %%
def histEquali(img):
    img = (img).astype(int).astype(np.uint16)
#     print(img.shape,img.dtype)
    op = exposure.equalize_hist(exposure.equalize_adapthist(img.reshape(img.shape[0],img.shape[1]))).reshape(img.shape[0],img.shape[1],1)
#     print(img.shape,img.dtype)
    return op

# %%
def load_data(image_dir):
    images = []
    y = []
    label_dict = {}
    classNum = 0
    for class1 in tqdm(sorted(os.listdir(image_dir))):
        for file_name in os.listdir(os.path.join(image_dir,class1)):
            img = cv2.resize(cv2.cvtColor(cv2.imread(os.path.join(image_dir,class1,file_name)),cv2.COLOR_BGR2GRAY),(224,224))
            img = histEquali(img)
            images.append(img / 255.)
            y.append(classNum)
        label_dict[classNum] = class1
        classNum += 1
    print(f'Loaded {len(images)} images from {image_dir} directory')
    images = np.array(images)
    images = images.reshape(-1,224,224,1)
    y = np.array(y)
    return images,y,label_dict

# %%
def show_samples(X,y,label_dict,n=20):
    for class1 in label_dict.keys():
        imgs = X[y == class1][:n]
        j = 10
        i = n // 10
        plt.figure(figsize=(15,3))
        for (c,img) in enumerate(imgs,1):
            plt.subplot(i,j,c)
            plt.imshow(img.reshape(224,224), cmap='gray')
            plt.xticks([])
            plt.yticks([])
        plt.suptitle(f'Tumor: {label_dict[class1]}')

# %% [markdown]
# We load all the images in our RAM

# %%
train_images, train_labels,label_dict = load_data(image_dir+'train/')
val_images, val_labels,_ = load_data(image_dir+'val/')
test_images, test_labels,_ = load_data(image_dir+'test/')

train_images[0].shape, val_images[0].shape, test_images[0].shape, label_dict
# Out:
# 100%|██████████| 2/2 [03:02<00:00, 91.11s/it]
# Loaded 5216 images from /kaggle/input/chest-xray-pneumonia/chest_xray/train/ directory
# 100%|██████████| 2/2 [00:00<00:00,  3.67it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Loaded 16 images from /kaggle/input/chest-xray-pneumonia/chest_xray/val/ directory
# 100%|██████████| 2/2 [00:21<00:00, 10.51s/it]
# Loaded 624 images from /kaggle/input/chest-xray-pneumonia/chest_xray/test/ directory
# ((224, 224, 1), (224, 224, 1), (224, 224, 1), {0: 'NORMAL', 1: 'PNEUMONIA'})

# %%
np.unique(train_labels,return_counts=True), np.unique(val_labels,return_counts=True), np.unique(test_labels,return_counts=True)
# Out:
# ((array([0, 1]), array([1341, 3875])),
#  (array([0, 1]), array([8, 8])),
#  (array([0, 1]), array([234, 390])))

# %% [markdown]
# # View Data in Train, Test, Validation Sets

# %% [markdown]
# While training the model using these datasets, I was not getting a good accuracy. So, I decided to concatenate all the datasets and from this master dataset, randomly create train, validation, test splits

# %%
img_dataset = np.concatenate([train_images,test_images,val_images],axis=0)
img_labels = np.concatenate([train_labels,test_labels,val_labels],axis=0)

shuffler = np.random.permutation(len(img_dataset))
img_dataset = img_dataset[shuffler]
img_labels = img_labels[shuffler]

# %%
train_s = int(0.9 * len(img_dataset))
val_s = int(0.05 * len(img_dataset))
test_s = int(0.05 * len(img_dataset))

train_images = img_dataset[:train_s,:]
train_labels = img_labels[:train_s]

val_images = img_dataset[train_s:train_s+val_s,:]
val_labels = img_labels[train_s:train_s+val_s]

test_images = img_dataset[train_s+val_s:,:]
test_labels = img_labels[train_s+val_s:]

# %% [markdown]
# We can see that the distribution of classes in all 3 datasets is fairly similar

# %%
np.unique(train_labels,return_counts=True), np.unique(val_labels,return_counts=True), np.unique(test_labels,return_counts=True)
# Out:
# ((array([0, 1]), array([1444, 3826])),
#  (array([0, 1]), array([ 61, 231])),
#  (array([0, 1]), array([ 78, 216])))

# %%
show_samples(train_images,train_labels,label_dict)

# %%
show_samples(val_images,val_labels,label_dict)

# %%
show_samples(test_images,test_labels,label_dict)

# %% [markdown]
# Since we have around 4k images in our training dataset, and since this task shouldn't need a complex CNN architecture, I skipped using data augmentation. Also, the dataset looks fairly similar in terms of scale, rotation, translation again deeming data augmentation not so important. However, if you want to use this for real-life testing, data augmentation could really boost such test accuracy.

# %% [markdown]
# # Model Selection
#
# Logically speaking, as a human there don't seem to be many features that would be needed for classification. So, I considered using 2 Conv layers and 2 Fully Connected with layers. Now, there are many optimizations and hyperparameters that I was considering. In my opinion, regularization is something that has no harm if used even in places where it's not needed. This is a default optimization.
#
# Along with this, I was skeptical about the boost in accuracy by using Dropout and Batch Normalization. So I'll try all 4 possibilities and in the end on the basis of validation set accuracy, I'll select the best model and evaluate its accuracy on test set.
#
# Since, this is diagnosis of disease, we could have false positives (though undesirable), but we should not have very few false negatives. Thus, we give more weightage to Recall as compared to Precision. Thus, we also consider this metric while comparing the models.

# %%
models = []
histories = []
modelValResults = []

num_epochs = 40
batch_size = 32

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=8000,
    decay_rate=0.001)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# %%
def recall_m(y_true,y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    pos = K.sum(K.round(K.clip(y_true, 0, 1)))
    return tp/(pos + K.epsilon())
def precision_m(y_true,y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predpos = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return tp/(predpos + K.epsilon())
def f1_score(y_true,y_pred):
    rec = recall_m(y_true,y_pred)
    prec = precision_m(y_true,y_pred)
    return 2 * (prec * rec) / (prec + rec)

# %% [markdown]
# ## Model 1 - 2 CONV-Max Pooling Units and 2 FC layers

# %%
model = Sequential()

model.add(Conv2D(64,kernel_size=5,input_shape=(224,224,1),padding='same',kernel_regularizer='l2'))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
# model.add(Dropout(0.25))

model.add(Conv2D(128,kernel_size=3,padding='same',kernel_regularizer='l2'))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4),strides=(4,4)))
# model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(100,activation='relu',kernel_regularizer='l2'))
model.add(Dense(1,activation='sigmoid'))

model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy',recall_m,f1_score]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1664
# _________________________________________________________________
# activation (Activation)      (None, 224, 224, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 100)               10035300
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,110,921
# Trainable params: 10,110,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_images,train_labels,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_data=(val_images,val_labels)
)
# Out:
# Train on 5270 samples, validate on 292 samples
# Epoch 1/40
# 5270/5270 [==============================] - 13s 2ms/sample - loss: 0.9175 - accuracy: 0.7230 - recall_m: 0.9899 - f1_score: nan - val_loss: 0.5246 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 2/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5882 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8383 - val_loss: 0.5200 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 3/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5877 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5146 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 4/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5886 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5199 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 5/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5877 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5215 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 6/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5880 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 7/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5877 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5265 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 8/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5877 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5255 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 9/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5879 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8381 - val_loss: 0.5234 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 10/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5874 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5200 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 11/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5876 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5231 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 12/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5875 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5225 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 13/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5875 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5240 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 14/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5263 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 15/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5874 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5231 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 16/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8394 - val_loss: 0.5240 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 17/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5242 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 18/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5224 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 19/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5230 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 20/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5219 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 21/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8384 - val_loss: 0.5242 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 22/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5245 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 23/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5246 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 24/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5235 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 25/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 26/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 27/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 28/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8392 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 29/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 30/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8390 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 31/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8384 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 32/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8390 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 33/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 34/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 35/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8390 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 36/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8382 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 37/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 38/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8392 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 39/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 40/40
# 5270/5270 [==============================] - 8s 1ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794

# %%
models.append(model)
histories.append(history)
evaltn = [1] + model.evaluate(val_images,val_labels)
modelValResults.append(evaltn)
print(f'Model\'s Performance on Validation Set - Loss: {evaltn[1]}, Accuracy: {evaltn[2]}, Recall: {evaltn[3]}, F1-score: {evaltn[4]}')
# Out:
# 292/292 [==============================] - 0s 610us/sample - loss: 0.5238 - accuracy: 0.7911 - recall_m: 1.0000 - f1_score: 0.8794
# Model's Performance on Validation Set - Loss: 0.5237547379650481, Accuracy: 0.7910959124565125, Recall: 1.0, F1-score: 0.8794103860855103

# %%
model.save('pneumonia-1.h5')

# %% [markdown]
# ## Model 2 - 2 Conv-Max Pooling-Dropout 2 FC Layers

# %%
model = Sequential()

model.add(Conv2D(64,kernel_size=5,input_shape=(224,224,1),padding='same',kernel_regularizer='l2'))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,kernel_size=3,padding='same',kernel_regularizer='l2'))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4),strides=(4,4)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(100,activation='relu',kernel_regularizer='l2'))
model.add(Dense(1,activation='sigmoid'))

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=8000,
    decay_rate=0.001)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy',recall_m,f1_score]
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 224, 224, 64)      1664
# _________________________________________________________________
# activation_2 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10035300
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,110,921
# Trainable params: 10,110,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_images,train_labels,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_data=(val_images,val_labels)
)
# Out:
# Train on 5270 samples, validate on 292 samples
# Epoch 1/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.9050 - accuracy: 0.7201 - recall_m: 0.9871 - f1_score: nan - val_loss: 0.5268 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 2/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5890 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5243 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 3/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5882 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5190 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 4/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5884 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8381 - val_loss: 0.5217 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 5/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5881 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5251 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 6/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5878 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5256 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 7/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5878 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5315 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 8/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5882 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5255 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 9/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5878 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 10/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5877 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5228 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 11/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5878 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8390 - val_loss: 0.5241 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 12/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5878 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8383 - val_loss: 0.5286 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 13/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5875 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5295 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 14/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5875 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5265 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 15/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5874 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8392 - val_loss: 0.5228 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 16/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5875 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5261 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 17/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5874 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5240 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 18/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5874 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5243 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 19/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5235 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 20/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5874 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8392 - val_loss: 0.5244 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 21/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8382 - val_loss: 0.5232 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 22/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 23/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5244 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 24/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5233 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 25/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 26/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8391 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 27/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8390 - val_loss: 0.5242 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 28/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8392 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 29/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8389 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 30/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5873 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8386 - val_loss: 0.5236 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 31/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 32/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 33/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 34/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 35/40
# 5270/5270 [==============================] - 9s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8385 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 36/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8390 - val_loss: 0.5239 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 37/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8394 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 38/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8387 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 39/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8388 - val_loss: 0.5237 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 40/40
# 5270/5270 [==============================] - 8s 2ms/sample - loss: 0.5872 - accuracy: 0.7260 - recall_m: 1.0000 - f1_score: 0.8380 - val_loss: 0.5238 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794

# %%
models.append(model)
histories.append(history)
evaltn = [2] + model.evaluate(val_images,val_labels)
modelValResults.append(evaltn)
print(f'Model\'s Performance on Validation Set - Loss: {evaltn[1]}, Accuracy: {evaltn[2]}, Recall: {evaltn[3]}, F1-score: {evaltn[4]}')
# Out:
# 292/292 [==============================] - 0s 612us/sample - loss: 0.5238 - accuracy: 0.7911 - recall_m: 1.0000 - f1_score: 0.8794
# Model's Performance on Validation Set - Loss: 0.5237540055627692, Accuracy: 0.7910959124565125, Recall: 1.0, F1-score: 0.8794103860855103

# %%
model.save('pneumonia-2.h5')

# %% [markdown]
# ## Model 3 - 2 Conv-BatchNorm-MaxPooling-Dropout 2 FC Layers

# %%
model = Sequential()

model.add(Conv2D(64,kernel_size=5,input_shape=(224,224,1),padding='same',kernel_regularizer='l2'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,kernel_size=3,padding='same',kernel_regularizer='l2'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4),strides=(4,4)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(100,activation='relu',kernel_regularizer='l2'))
model.add(Dense(1,activation='sigmoid'))

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=8000,
    decay_rate=0.001)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy',recall_m,f1_score]
)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 224, 224, 64)      1664
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 64)      256
# _________________________________________________________________
# activation_4 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 128)     512
# _________________________________________________________________
# activation_5 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10035300
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,111,689
# Trainable params: 10,111,305
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit(
    train_images,train_labels,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_data=(val_images,val_labels)
)
# Out:
# Train on 5270 samples, validate on 292 samples
# Epoch 1/40
# 5270/5270 [==============================] - 12s 2ms/sample - loss: 10.6054 - accuracy: 0.7888 - recall_m: 0.9221 - f1_score: nan - val_loss: 1.1074 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 2/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.6382 - accuracy: 0.8750 - recall_m: 0.9254 - f1_score: 0.9135 - val_loss: 0.7616 - val_accuracy: 0.8356 - val_recall_m: 1.0000 - val_f1_score: 0.9002
# Epoch 3/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.4374 - accuracy: 0.8915 - recall_m: 0.9354 - f1_score: 0.9248 - val_loss: 0.7911 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 4/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.3815 - accuracy: 0.8979 - recall_m: 0.9373 - f1_score: 0.9285 - val_loss: 0.7524 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 5/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.3337 - accuracy: 0.9051 - recall_m: 0.9432 - f1_score: 0.9342 - val_loss: 0.7356 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 6/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.3148 - accuracy: 0.9118 - recall_m: 0.9461 - f1_score: 0.9381 - val_loss: 2.4871 - val_accuracy: 0.7945 - val_recall_m: 1.0000 - val_f1_score: 0.8810
# Epoch 7/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2980 - accuracy: 0.9087 - recall_m: 0.9446 - f1_score: 0.9369 - val_loss: 6.2813 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 8/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2825 - accuracy: 0.9173 - recall_m: 0.9485 - f1_score: 0.9423 - val_loss: 0.5834 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 9/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2749 - accuracy: 0.9165 - recall_m: 0.9494 - f1_score: 0.9417 - val_loss: 2.1279 - val_accuracy: 0.7979 - val_recall_m: 1.0000 - val_f1_score: 0.8825
# Epoch 10/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2736 - accuracy: 0.9131 - recall_m: 0.9440 - f1_score: 0.9390 - val_loss: 0.5578 - val_accuracy: 0.8356 - val_recall_m: 0.9957 - val_f1_score: 0.8999
# Epoch 11/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2588 - accuracy: 0.9190 - recall_m: 0.9482 - f1_score: 0.9430 - val_loss: 7.5057 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 12/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.2563 - accuracy: 0.9195 - recall_m: 0.9479 - f1_score: 0.9431 - val_loss: 4.1250 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 13/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.2428 - accuracy: 0.9216 - recall_m: 0.9521 - f1_score: 0.9453 - val_loss: 0.6559 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 14/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2384 - accuracy: 0.9258 - recall_m: 0.9524 - f1_score: 0.9473 - val_loss: 2.8813 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 15/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2412 - accuracy: 0.9239 - recall_m: 0.9505 - f1_score: 0.9467 - val_loss: 0.6658 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 16/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2302 - accuracy: 0.9275 - recall_m: 0.9558 - f1_score: 0.9493 - val_loss: 0.6614 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 17/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2248 - accuracy: 0.9311 - recall_m: 0.9558 - f1_score: 0.9518 - val_loss: 0.6591 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 18/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.2221 - accuracy: 0.9285 - recall_m: 0.9534 - f1_score: 0.9494 - val_loss: 0.3011 - val_accuracy: 0.8973 - val_recall_m: 0.9747 - val_f1_score: 0.9281
# Epoch 19/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2189 - accuracy: 0.9326 - recall_m: 0.9555 - f1_score: 0.9526 - val_loss: 0.3619 - val_accuracy: 0.8699 - val_recall_m: 0.9877 - val_f1_score: 0.9153
# Epoch 20/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2078 - accuracy: 0.9351 - recall_m: 0.9608 - f1_score: 0.9550 - val_loss: 0.3916 - val_accuracy: 0.8801 - val_recall_m: 0.9214 - val_f1_score: 0.9145
# Epoch 21/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2147 - accuracy: 0.9298 - recall_m: 0.9538 - f1_score: 0.9496 - val_loss: 0.6392 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 22/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2082 - accuracy: 0.9313 - recall_m: 0.9552 - f1_score: 0.9518 - val_loss: 0.6494 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 23/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.2066 - accuracy: 0.9340 - recall_m: 0.9571 - f1_score: 0.9536 - val_loss: 0.2443 - val_accuracy: 0.9144 - val_recall_m: 0.9795 - val_f1_score: 0.9382
# Epoch 24/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.2042 - accuracy: 0.9332 - recall_m: 0.9580 - f1_score: 0.9531 - val_loss: 0.2315 - val_accuracy: 0.9178 - val_recall_m: 0.9665 - val_f1_score: 0.9388
# Epoch 25/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2016 - accuracy: 0.9361 - recall_m: 0.9594 - f1_score: 0.9549 - val_loss: 0.2901 - val_accuracy: 0.8938 - val_recall_m: 0.9455 - val_f1_score: 0.9235
# Epoch 26/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1999 - accuracy: 0.9361 - recall_m: 0.9584 - f1_score: 0.9554 - val_loss: 0.6369 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 27/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1990 - accuracy: 0.9321 - recall_m: 0.9577 - f1_score: 0.9524 - val_loss: 0.3046 - val_accuracy: 0.9007 - val_recall_m: 0.9296 - val_f1_score: 0.9268
# Epoch 28/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1975 - accuracy: 0.9370 - recall_m: 0.9615 - f1_score: 0.9559 - val_loss: 0.2365 - val_accuracy: 0.9178 - val_recall_m: 0.9457 - val_f1_score: 0.9372
# Epoch 29/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1957 - accuracy: 0.9359 - recall_m: 0.9600 - f1_score: 0.9552 - val_loss: 0.2697 - val_accuracy: 0.9075 - val_recall_m: 0.9421 - val_f1_score: 0.9318
# Epoch 30/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.1989 - accuracy: 0.9338 - recall_m: 0.9581 - f1_score: 0.9538 - val_loss: 0.2308 - val_accuracy: 0.9178 - val_recall_m: 0.9574 - val_f1_score: 0.9375
# Epoch 31/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1916 - accuracy: 0.9343 - recall_m: 0.9582 - f1_score: 0.9542 - val_loss: 0.2251 - val_accuracy: 0.9144 - val_recall_m: 0.9574 - val_f1_score: 0.9356
# Epoch 32/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1939 - accuracy: 0.9380 - recall_m: 0.9601 - f1_score: 0.9566 - val_loss: 0.3107 - val_accuracy: 0.9007 - val_recall_m: 0.9261 - val_f1_score: 0.9268
# Epoch 33/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1918 - accuracy: 0.9366 - recall_m: 0.9581 - f1_score: 0.9549 - val_loss: 0.2290 - val_accuracy: 0.9178 - val_recall_m: 0.9665 - val_f1_score: 0.9388
# Epoch 34/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1891 - accuracy: 0.9391 - recall_m: 0.9601 - f1_score: 0.9577 - val_loss: 0.2285 - val_accuracy: 0.9144 - val_recall_m: 0.9622 - val_f1_score: 0.9364
# Epoch 35/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 0.1940 - accuracy: 0.9383 - recall_m: 0.9613 - f1_score: 0.9571 - val_loss: 0.2323 - val_accuracy: 0.9110 - val_recall_m: 0.9713 - val_f1_score: 0.9359
# Epoch 36/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1907 - accuracy: 0.9408 - recall_m: 0.9626 - f1_score: 0.9586 - val_loss: 0.2322 - val_accuracy: 0.9110 - val_recall_m: 0.9497 - val_f1_score: 0.9334
# Epoch 37/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1919 - accuracy: 0.9355 - recall_m: 0.9586 - f1_score: 0.9551 - val_loss: 0.2401 - val_accuracy: 0.9110 - val_recall_m: 0.9536 - val_f1_score: 0.9336
# Epoch 38/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1876 - accuracy: 0.9385 - recall_m: 0.9610 - f1_score: 0.9567 - val_loss: 0.2283 - val_accuracy: 0.9144 - val_recall_m: 0.9622 - val_f1_score: 0.9364
# Epoch 39/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1902 - accuracy: 0.9374 - recall_m: 0.9596 - f1_score: 0.9560 - val_loss: 0.2377 - val_accuracy: 0.9144 - val_recall_m: 0.9536 - val_f1_score: 0.9355
# Epoch 40/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1862 - accuracy: 0.9408 - recall_m: 0.9636 - f1_score: 0.9586 - val_loss: 0.2324 - val_accuracy: 0.9110 - val_recall_m: 0.9622 - val_f1_score: 0.9345

# %%
models.append(model)
histories.append(history)
evaltn = [3] + model.evaluate(val_images,val_labels)
modelValResults.append(evaltn)
print(f'Model\'s Performance on Validation Set - Loss: {evaltn[1]}, Accuracy: {evaltn[2]}, Recall: {evaltn[3]}, F1-score: {evaltn[4]}')
# Out:
# 292/292 [==============================] - 0s 711us/sample - loss: 0.2324 - accuracy: 0.9110 - recall_m: 0.9622 - f1_score: 0.9345
# Model's Performance on Validation Set - Loss: 0.23237256644523308, Accuracy: 0.9109588861465454, Recall: 0.9621689915657043, F1-score: 0.9345425367355347

# %%
model.save('pneumonia-3.h5')

# %% [markdown]
# ## Model 4 - 2 Conv-BatchNorm-MaxPooling 2 FC Layers

# %%
model = Sequential()

model.add(Conv2D(64,kernel_size=5,input_shape=(224,224,1),padding='same',kernel_regularizer='l2'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
# model.add(Dropout(0.25))

model.add(Conv2D(128,kernel_size=3,padding='same',kernel_regularizer='l2'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4,4),strides=(4,4)))
# model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(100,activation='relu',kernel_regularizer='l2'))
model.add(Dense(1,activation='sigmoid'))

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=8000,
    decay_rate=0.001)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy',recall_m,f1_score]
)

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 224, 224, 64)      1664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 224, 224, 64)      256
# _________________________________________________________________
# activation_6 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 112, 112, 128)     512
# _________________________________________________________________
# activation_7 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10035300
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 10,111,689
# Trainable params: 10,111,305
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit(
    train_images,train_labels,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_data=(val_images,val_labels)
)
# Out:
# Train on 5270 samples, validate on 292 samples
# Epoch 1/40
# 5270/5270 [==============================] - 11s 2ms/sample - loss: 7.5632 - accuracy: 0.8093 - recall_m: 0.9076 - f1_score: nan - val_loss: 1.1912 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 2/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.6534 - accuracy: 0.8926 - recall_m: 0.9351 - f1_score: 0.9246 - val_loss: 0.8152 - val_accuracy: 0.7979 - val_recall_m: 1.0000 - val_f1_score: 0.8825
# Epoch 3/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.4546 - accuracy: 0.9036 - recall_m: 0.9410 - f1_score: 0.9332 - val_loss: 0.6207 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 4/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.3575 - accuracy: 0.9156 - recall_m: 0.9447 - f1_score: 0.9406 - val_loss: 2.8072 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 5/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.3234 - accuracy: 0.9180 - recall_m: 0.9467 - f1_score: 0.9427 - val_loss: 5.7164 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 6/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2939 - accuracy: 0.9197 - recall_m: 0.9503 - f1_score: 0.9441 - val_loss: 18.8531 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 7/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2789 - accuracy: 0.9237 - recall_m: 0.9546 - f1_score: 0.9470 - val_loss: 3.4826 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 8/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2790 - accuracy: 0.9167 - recall_m: 0.9486 - f1_score: 0.9409 - val_loss: 1.4475 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 9/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2469 - accuracy: 0.9313 - recall_m: 0.9562 - f1_score: 0.9520 - val_loss: 4.4985 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 10/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2349 - accuracy: 0.9364 - recall_m: 0.9588 - f1_score: 0.9552 - val_loss: 19.3486 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 11/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2212 - accuracy: 0.9404 - recall_m: 0.9606 - f1_score: 0.9583 - val_loss: 0.3175 - val_accuracy: 0.8904 - val_recall_m: 0.9918 - val_f1_score: 0.9266
# Epoch 12/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2220 - accuracy: 0.9389 - recall_m: 0.9630 - f1_score: 0.9569 - val_loss: 6.0139 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 13/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.2057 - accuracy: 0.9438 - recall_m: 0.9665 - f1_score: 0.9609 - val_loss: 5.0417 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 14/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1909 - accuracy: 0.9499 - recall_m: 0.9705 - f1_score: 0.9645 - val_loss: 15.0407 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 15/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1867 - accuracy: 0.9505 - recall_m: 0.9684 - f1_score: 0.9651 - val_loss: 0.4865 - val_accuracy: 0.8767 - val_recall_m: 0.8365 - val_f1_score: 0.9019
# Epoch 16/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1774 - accuracy: 0.9545 - recall_m: 0.9735 - f1_score: 0.9680 - val_loss: 0.3357 - val_accuracy: 0.8699 - val_recall_m: 1.0000 - val_f1_score: 0.9170
# Epoch 17/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1769 - accuracy: 0.9512 - recall_m: 0.9698 - f1_score: 0.9658 - val_loss: 0.4259 - val_accuracy: 0.8253 - val_recall_m: 1.0000 - val_f1_score: 0.8953
# Epoch 18/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1682 - accuracy: 0.9556 - recall_m: 0.9710 - f1_score: 0.9688 - val_loss: 0.9092 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 19/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1622 - accuracy: 0.9598 - recall_m: 0.9753 - f1_score: 0.9717 - val_loss: 4.2748 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 20/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1549 - accuracy: 0.9628 - recall_m: 0.9783 - f1_score: 0.9739 - val_loss: 2.4884 - val_accuracy: 0.7911 - val_recall_m: 1.0000 - val_f1_score: 0.8794
# Epoch 21/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1574 - accuracy: 0.9611 - recall_m: 0.9780 - f1_score: 0.9728 - val_loss: 0.9837 - val_accuracy: 0.7774 - val_recall_m: 0.7082 - val_f1_score: 0.8252
# Epoch 22/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1476 - accuracy: 0.9653 - recall_m: 0.9807 - f1_score: 0.9757 - val_loss: 0.3656 - val_accuracy: 0.9110 - val_recall_m: 0.9751 - val_f1_score: 0.9359
# Epoch 23/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1463 - accuracy: 0.9645 - recall_m: 0.9802 - f1_score: 0.9751 - val_loss: 0.6359 - val_accuracy: 0.8630 - val_recall_m: 0.8169 - val_f1_score: 0.8919
# Epoch 24/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1415 - accuracy: 0.9672 - recall_m: 0.9813 - f1_score: 0.9771 - val_loss: 0.4251 - val_accuracy: 0.8870 - val_recall_m: 0.8527 - val_f1_score: 0.8981
# Epoch 25/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1377 - accuracy: 0.9685 - recall_m: 0.9805 - f1_score: 0.9779 - val_loss: 0.4033 - val_accuracy: 0.8425 - val_recall_m: 0.8258 - val_f1_score: 0.8675
# Epoch 26/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1377 - accuracy: 0.9666 - recall_m: 0.9788 - f1_score: 0.9762 - val_loss: 0.4033 - val_accuracy: 0.8630 - val_recall_m: 0.8184 - val_f1_score: 0.8897
# Epoch 27/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1330 - accuracy: 0.9717 - recall_m: 0.9840 - f1_score: 0.9803 - val_loss: 0.3170 - val_accuracy: 0.9007 - val_recall_m: 0.9957 - val_f1_score: 0.9322
# Epoch 28/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1317 - accuracy: 0.9721 - recall_m: 0.9850 - f1_score: 0.9806 - val_loss: 0.3778 - val_accuracy: 0.8904 - val_recall_m: 0.8517 - val_f1_score: 0.9099
# Epoch 29/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1300 - accuracy: 0.9719 - recall_m: 0.9831 - f1_score: 0.9801 - val_loss: 0.3050 - val_accuracy: 0.9178 - val_recall_m: 0.9756 - val_f1_score: 0.9398
# Epoch 30/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1299 - accuracy: 0.9708 - recall_m: 0.9838 - f1_score: 0.9798 - val_loss: 0.4241 - val_accuracy: 0.8459 - val_recall_m: 0.8106 - val_f1_score: 0.8786
# Epoch 31/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1276 - accuracy: 0.9744 - recall_m: 0.9864 - f1_score: 0.9823 - val_loss: 0.3222 - val_accuracy: 0.8973 - val_recall_m: 0.8754 - val_f1_score: 0.9045
# Epoch 32/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1257 - accuracy: 0.9750 - recall_m: 0.9854 - f1_score: 0.9825 - val_loss: 0.2499 - val_accuracy: 0.9075 - val_recall_m: 0.9664 - val_f1_score: 0.9335
# Epoch 33/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1247 - accuracy: 0.9742 - recall_m: 0.9860 - f1_score: 0.9821 - val_loss: 0.2913 - val_accuracy: 0.9144 - val_recall_m: 0.8989 - val_f1_score: 0.9162
# Epoch 34/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1234 - accuracy: 0.9751 - recall_m: 0.9864 - f1_score: 0.9828 - val_loss: 0.2478 - val_accuracy: 0.9075 - val_recall_m: 0.8992 - val_f1_score: 0.9126
# Epoch 35/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1230 - accuracy: 0.9755 - recall_m: 0.9875 - f1_score: 0.9828 - val_loss: 0.2495 - val_accuracy: 0.9075 - val_recall_m: 0.8994 - val_f1_score: 0.9129
# Epoch 36/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1224 - accuracy: 0.9763 - recall_m: 0.9865 - f1_score: 0.9832 - val_loss: 0.2325 - val_accuracy: 0.9110 - val_recall_m: 0.9119 - val_f1_score: 0.9156
# Epoch 37/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1211 - accuracy: 0.9765 - recall_m: 0.9885 - f1_score: 0.9833 - val_loss: 0.2367 - val_accuracy: 0.9075 - val_recall_m: 0.8994 - val_f1_score: 0.9126
# Epoch 38/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1216 - accuracy: 0.9755 - recall_m: 0.9864 - f1_score: 0.9830 - val_loss: 0.2307 - val_accuracy: 0.9212 - val_recall_m: 0.9534 - val_f1_score: 0.9392
# Epoch 39/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1204 - accuracy: 0.9757 - recall_m: 0.9866 - f1_score: 0.9830 - val_loss: 0.2324 - val_accuracy: 0.9144 - val_recall_m: 0.9659 - val_f1_score: 0.9366
# Epoch 40/40
# 5270/5270 [==============================] - 10s 2ms/sample - loss: 0.1201 - accuracy: 0.9757 - recall_m: 0.9882 - f1_score: 0.9831 - val_loss: 0.2465 - val_accuracy: 0.9075 - val_recall_m: 0.8994 - val_f1_score: 0.9129

# %%
models.append(model)
histories.append(history)
evaltn = [4] + model.evaluate(val_images,val_labels)
modelValResults.append(evaltn)
print(f'Model\'s Performance on Validation Set - Loss: {evaltn[1]}, Accuracy: {evaltn[2]}, Recall: {evaltn[3]}, F1-score: {evaltn[4]}')
# Out:
# 292/292 [==============================] - 0s 724us/sample - loss: 0.2465 - accuracy: 0.9075 - recall_m: 0.8994 - f1_score: 0.9129
# Model's Performance on Validation Set - Loss: 0.24651611259538833, Accuracy: 0.9075342416763306, Recall: 0.8993524312973022, F1-score: 0.9129141569137573

# %%
model.save('pneumonia-4.h5')

# %% [markdown]
# # Compare Performances of 4 Models

# %%
pd.DataFrame(modelValResults,columns=['Model No','Validation Loss','Validation Accuracy','Recall','F1-Score'])
# Out:
#    Model No  Validation Loss  Validation Accuracy    Recall  F1-Score
# 0         1         0.523755             0.791096  1.000000  0.879410
# 1         2         0.523754             0.791096  1.000000  0.879410
# 2         3         0.232373             0.910959  0.962169  0.934543
# 3         4         0.246516             0.907534  0.899352  0.912914

# %%
for i in range(len(histories)):
    history = histories[i]
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(history.epoch) + 1)

    plt.figure(figsize=(15,5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Set')
    plt.plot(epochs_range, val_acc, label='Val Set')
    plt.legend(loc="best")
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Model Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Set')
    plt.plot(epochs_range, val_loss, label='Val Set')
    plt.legend(loc="best")
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Model Loss')
    
    plt.suptitle('Model '+str(i+1))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## View Details of Best Model based on Validation Accuracy

# %%
bestModelI = np.argmax(np.array(modelValResults)[:,2],axis=0)
history = histories[bestModelI]
print('On the basis of validation set accuracy, the best model seems to be Model ',(bestModelI+1))
# Out:
# On the basis of validation set accuracy, the best model seems to be Model  3

# %%
history = histories[bestModelI]
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Performance on Test Set

# %%
model = models[bestModelI]
preds = (model.predict(test_images) >= 0.5).astype(int)
sns.heatmap(confusion_matrix(test_labels,preds),annot=True)

print(np.unique(preds,return_counts=True))

# model.evaluate(test_images,OneHotEncoder().fit_transform(test_labels.reshape(1,-1)).toarray())
evaltn = model.evaluate(test_images,test_labels)
print(f'Model\'s Performance on Test Set - Loss: {evaltn[0]}, Accuracy: {evaltn[1]}, Recall: {evaltn[2]}, F1-score: {evaltn[3]}')
# Out:
# (array([0, 1]), array([ 72, 222]))
# 294/294 [==============================] - 0s 707us/sample - loss: 0.1969 - accuracy: 0.9456 - recall_m: 0.9673 - f1_score: 0.9589
# Model's Performance on Test Set - Loss: 0.1969038102091575, Accuracy: 0.9455782175064087, Recall: 0.9672689437866211, F1-score: 0.9589419364929199

# %% [markdown]
# ## View Details of Best Model based on Recall

# %%
bestModelI = np.argmax(np.array(modelValResults)[:,3],axis=0)
history = histories[bestModelI]
print('On the basis of recall, the best model seems to be Model ',(bestModelI+1))
# Out:
# On the basis of recall, the best model seems to be Model  1

# %%
history = histories[bestModelI]
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Performance on Test Set

# %%
model = models[bestModelI]
preds = (model.predict(test_images) >= 0.5).astype(int)
sns.heatmap(confusion_matrix(test_labels,preds),annot=True)

print(np.unique(preds,return_counts=True))

# model.evaluate(test_images,OneHotEncoder().fit_transform(test_labels.reshape(1,-1)).toarray())
evaltn = model.evaluate(test_images,test_labels)
print(f'Model\'s Performance on Test Set - Loss: {evaltn[0]}, Accuracy: {evaltn[1]}, Recall: {evaltn[2]}, F1-score: {evaltn[3]}')
# Out:
# (array([1]), array([294]))
# 294/294 [==============================] - 0s 577us/sample - loss: 0.5787 - accuracy: 0.7347 - recall_m: 1.0000 - f1_score: 0.8564
# Model's Performance on Test Set - Loss: 0.5787238831422767, Accuracy: 0.7346938848495483, Recall: 1.0, F1-score: 0.8563821911811829

# %% [markdown]
# ## View Details of Best Model based on F1-Score

# %%
bestModelI = np.argmax(np.array(modelValResults)[:,4],axis=0)
history = histories[bestModelI]
print('On the basis of F1-Score, the best model seems to be Model ',(bestModelI+1))
# Out:
# On the basis of F1-Score, the best model seems to be Model  3

# %%
history = histories[bestModelI]
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Performance on Test Set

# %%
model = models[bestModelI]
preds = (model.predict(test_images) >= 0.5).astype(int)
sns.heatmap(confusion_matrix(test_labels,preds),annot=True)

print(np.unique(preds,return_counts=True))

# model.evaluate(test_images,OneHotEncoder().fit_transform(test_labels.reshape(1,-1)).toarray())
evaltn = model.evaluate(test_images,test_labels)
print(f'Model\'s Performance on Test Set - Loss: {evaltn[0]}, Accuracy: {evaltn[1]}, Recall: {evaltn[2]}, F1-score: {evaltn[3]}')
# Out:
# (array([0, 1]), array([ 72, 222]))
# 294/294 [==============================] - 0s 690us/sample - loss: 0.1969 - accuracy: 0.9456 - recall_m: 0.9673 - f1_score: 0.9589
# Model's Performance on Test Set - Loss: 0.1969038102091575, Accuracy: 0.9455782175064087, Recall: 0.9672689437866211, F1-score: 0.9589419364929199
